# %%
import pandas as pd

# %% [markdown]
# # 1. Series (1D)

# %%
series=pd.Series([1,2,23,4],index=["a",'b','c','d'])
series2=pd.Series([1,2,3,4])

# %%
series
# Out:
# a     1
# b     2
# c    23
# d     4
# dtype: int64

# %%
series2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
print(series['a'])
# Out:
# 1

# %% [markdown]
# # 2. DataFrame (2D)

# %%
dataframe=pd.DataFrame({
    "name":["anil","sunil","reshma"],
    "marks":[91,67,100]
})

# %%
dict={
    "name":["anil","sunil","reshma"],
    "marks":[91,67,100]
}

dataframe_1=pd.DataFrame(dict)

# %%
data_frame_3=[["anil",91],["sunil",100]]
dataframe_3=pd.DataFrame(data_frame_3,columns=["name","marks"])

# %%
dataframe
# Out:
#      name  marks
# 0    anil     91
# 1   sunil     67
# 2  reshma    100

# %%
dataframe_1
# Out:
#      name  marks
# 0    anil     91
# 1   sunil     67
# 2  reshma    100

# %%
dataframe_3
# Out:
#     name  marks
# 0   anil     91
# 1  sunil    100

# %% [markdown]
# # 3 Data Import & Export Operations

# %% [markdown]
# ```python
# pd.read_csv('file.csv')
# pd.read_excel('file.xlsx')
# pd.read_json('file.json')
# pd.read_sql(query, connection)
# ```

# %%
student_data=pd.read_csv(r"R:\DATA_ANALYTICS\python\pandas\students.csv")
courses_data=pd.read_csv(r"R:\DATA_ANALYTICS\python\pandas\courses.csv")
enrolment_data=pd.read_csv(r"R:\DATA_ANALYTICS\python\pandas\enrollments.csv")

# %% [markdown]
# ```python
# df.to_csv('out.csv', index=False)
# df.to_excel('out.xlsx')
# df.to_json('out.json')
# ```

# %% [markdown]
# ```python

# %% [markdown]
# # 4 Basic Data Inspection

# %%
student_data.head()
# Out:
#    student_id   name   age        department
# 0           1   Amit  20.0  Computer Science
# 1           2   Neha  21.0        Mechanical
# 2           3  Rahul  19.0        Electrical
# 3           4  Priya  22.0  Computer Science
# 4           5  Karan   NaN             Civil

# %%
student_data.tail()
# Out:
#     student_id     name   age        department
# 45          46    Rekha  21.0        Electrical
# 46          47    Lalit  22.0             Civil
# 47          48    Swati  20.0  Computer Science
# 48          49  Prakash  21.0               NaN
# 49          50   Monika  22.0        Mechanical

# %%
student_data.shape
# Out:
# (50, 4)

# %%
student_data.columns
# Out:
# Index(['student_id', 'name', 'age', 'department'], dtype='object')

# %%
student_data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  50 non-null     int64
#  1   name        50 non-null     object
#  2   age         42 non-null     float64
#  3   department  47 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.7+ KB

# %%
student_data.describe()
# Out:
#        student_id        age
# count    50.00000  42.000000
# mean     25.50000  20.738095
# std      14.57738   1.127473
# min       1.00000  19.000000
# 25%      13.25000  20.000000
# 50%      25.50000  21.000000
# 75%      37.75000  22.000000
# max      50.00000  23.000000

# %% [markdown]
# ``` python

# %% [markdown]
# ```python

# %% [markdown]
# # 5 Column Operations

# %% [markdown]
# SELECT COLUMN

# %%
age=student_data['age']

# %% [markdown]
# SELECT MULTIPLE COLUMNS

# %%
name_age=student_data[['name','age']]

# %% [markdown]
# ADD NEW COLUMNS

# %%
enrolment_data['passed']=enrolment_data['marks']>80

# %%
enrolment_data.head()
# Out:
#   enrollment_id  student_id  course_id  semester  marks        date  passed
# 0             1         1.0      101.0       1.0   85.0  2024-01-15    True
# 1             2         1.0      102.0       1.0   78.0  2024-01-15   False
# 2             3         2.0      201.0       1.0   72.0  2024-01-16   False
# 3             4         3.0      301.0       1.0   68.0  2024-01-16   False
# 4             5         4.0      101.0       1.0   91.0  2024-01-17    True

# %% [markdown]
# RENAME COLUMN

# %%
student_data.rename(columns={"name":"new_name"},inplace=True)

# %%
student_data.head()
# Out:
#    student_id new_name   age        department
# 0           1     Amit  20.0  Computer Science
# 1           2     Neha  21.0        Mechanical
# 2           3    Rahul  19.0        Electrical
# 3           4    Priya  22.0  Computer Science
# 4           5    Karan   NaN             Civil

# %% [markdown]
# DROP column

# %%
student_data.drop("new_name",axis=1).head()
# Out:
#    student_id   age        department
# 0           1  20.0  Computer Science
# 1           2  21.0        Mechanical
# 2           3  19.0        Electrical
# 3           4  22.0  Computer Science
# 4           5   NaN             Civil

# %% [markdown]
# ```python

# %% [markdown]
# ```python

# %% [markdown]
# # 6 Row Operations

# %% [markdown]
# iloc

# %%
student_data.iloc[::].head()
# Out:
#    student_id new_name   age        department
# 0           1     Amit  20.0  Computer Science
# 1           2     Neha  21.0        Mechanical
# 2           3    Rahul  19.0        Electrical
# 3           4    Priya  22.0  Computer Science
# 4           5    Karan   NaN             Civil

# %% [markdown]
# FILTER DATA

# %%
student_data[student_data["age"]>21]
# Out:
#     student_id new_name   age        department
# 3            4    Priya  22.0  Computer Science
# 8            9    Rohan  22.0        Electrical
# 10          11   Vikram  23.0             Civil
# 14          15   Suresh  22.0             Civil
# 18          19    Mohan  22.0               NaN
# 22          23    Nitin  22.0             Civil
# 26          27   Harish  22.0             Civil
# 30          31     Ajay  22.0             Civil
# 34          35     Alok  22.0             Civil
# 38          39   Girish  22.0             Civil
# 42          43    Anand  22.0             Civil
# 46          47    Lalit  22.0             Civil
# 49          50   Monika  22.0        Mechanical

# %% [markdown]
# DROP ROW

# %%
student_data.drop(1).head()
# Out:
#    student_id new_name   age        department
# 0           1     Amit  20.0  Computer Science
# 2           3    Rahul  19.0        Electrical
# 3           4    Priya  22.0  Computer Science
# 4           5    Karan   NaN             Civil
# 5           6    Sneha  20.0               NaN

# %% [markdown]
#  # 8 Sorting Operations

# %% [markdown]
# SORT values

# %%
student_data.sort_values("age").head(5)
# Out:
#     student_id new_name   age        department
# 2            3    Rahul  19.0        Electrical
# 43          44   Shruti  19.0  Computer Science
# 37          38    Komal  19.0        Electrical
# 7            8    Pooja  19.0        Mechanical
# 31          32    Payal  19.0  Computer Science

# %%
student_data.sort_values("age",ascending=False).head()
# Out:
#     student_id new_name   age        department
# 10          11   Vikram  23.0             Civil
# 49          50   Monika  22.0        Mechanical
# 30          31     Ajay  22.0             Civil
# 26          27   Harish  22.0             Civil
# 3            4    Priya  22.0  Computer Science

# %% [markdown]
# # 9 Handling Missing Values

# %% [markdown]
# IS NULL , NOTNULL

# %%
student_data.isnull().sum()
# Out:
# student_id    0
# new_name      0
# age           8
# department    3
# dtype: int64

# %%
student_data.notnull().sum()
# Out:
# student_id    50
# new_name      50
# age           42
# department    47
# dtype: int64

# %% [markdown]
# **dropna**

# %%
student_data.dropna().head()
# Out:
#    student_id new_name   age        department
# 0           1     Amit  20.0  Computer Science
# 1           2     Neha  21.0        Mechanical
# 2           3    Rahul  19.0        Electrical
# 3           4    Priya  22.0  Computer Science
# 6           7    Arjun  21.0  Computer Science

# %%
student_data.dropna(axis=1).head()
# Out:
#    student_id new_name
# 0           1     Amit
# 1           2     Neha
# 2           3    Rahul
# 3           4    Priya
# 4           5    Karan

# %% [markdown]
# **FILL NA**

# %%
student_data.fillna(0).head()
# Out:
#    student_id new_name   age        department
# 0           1     Amit  20.0  Computer Science
# 1           2     Neha  21.0        Mechanical
# 2           3    Rahul  19.0        Electrical
# 3           4    Priya  22.0  Computer Science
# 4           5    Karan   0.0             Civil

# %%
student_data["age"].fillna(student_data["age"].mode()[0],inplace=True)
# Out:
# C:\Users\layap\AppData\Local\Temp\ipykernel_15008\3102677726.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   student_data["age"].fillna(student_data["age"].mode()[0],inplace=True)

# %% [markdown]
# # 10 Data Type Operations

# %%
student_data.dtypes
# Out:
# student_id      int64
# new_name       object
# age           float64
# department     object
# dtype: object

# %%
student_data["age"]=student_data["age"].astype(int)

# %% [markdown]
# # Mathematical & Statistical Operations

# %%
student_data["age"].max()
# Out:
# 23

# %%
student_data["age"].min()
# Out:
# 19

# %%
student_data["age"].count()
# Out:
# 50

# %%
student_data["age"].mean()
# Out:
# 20.94

# %%
student_data["age"].median()
# Out:
# 21.0

# %%
student_data["age"].var()
# Out:
# 1.2820408163265307

# %%
student_data["age"].std()
# Out:
# 1.1322724125962491

# %% [markdown]
# fi

# %% [markdown]
# # 11 apply ,map , applymap

# %%
student_data["age"]=student_data["age"].apply(lambda x : x+5)

# %%
student_data["age_grade"]=student_data["age"].map({25:"a",26:"b"})

# %% [markdown]
# ```python
# df.applymap(lambda x: x*2 if type(x)==int else x)
# ```

# %% [markdown]
# # 1️⃣2️⃣ GroupBy Operations

# %%
student_data.columns
# Out:
# Index(['student_id', 'new_name', 'age', 'department', 'age_grade'], dtype='object')

# %%
student_data.groupby('department')['age'].max()
# Out:
# department
# Civil               28
# Computer Science    27
# Electrical          27
# Mechanical          27
# Name: age, dtype: int64

# %%
student_data.groupby('department').agg({'age':["mean","max"]})
# Out:
#                         age
#                        mean max
# department
# Civil             27.100000  28
# Computer Science  25.571429  27
# Electrical        25.727273  27
# Mechanical        25.583333  27

# %% [markdown]
# # 1️⃣3️⃣ Merge, Join & Concat

# %% [markdown]
# MERGE

# %% [markdown]
# ```python # INNER JOIN
# inner_join = pd.merge(courses_data, student_data, on='department', how='inner')
#
# # LEFT JOIN
# left_join = pd.merge(courses_data, student_data, on='department', how='left')
#
# # RIGHT JOIN
# right_join = pd.merge(courses_data, student_data, on='department', how='right')
#
# # OUTER (FULL) JOIN
# outer_join = pd.merge(courses_data, student_data, on='department', how='outer')
#
# # CROSS JOIN (no key needed)
# cross_join = pd.merge(courses_data, student_data, how='cross')
# ```

# %%
pd.merge(courses_data,student_data,on='department',how='inner')
# Out:
#      course_id                 course_name        department  credits  \
# 0          101          Python Programming  Computer Science      4.0
# 1          101          Python Programming  Computer Science      4.0
# 2          101          Python Programming  Computer Science      4.0
# 3          101          Python Programming  Computer Science      4.0
# 4          101          Python Programming  Computer Science      4.0
# ..         ...                         ...               ...      ...
# 231        403  Transportation Engineering             Civil      NaN
# 232        403  Transportation Engineering             Civil      NaN
# 233        403  Transportation Engineering             Civil      NaN
# 234        403  Transportation Engineering             Civil      NaN
# 235        403  Transportation Engineering             Civil      NaN
#
#      student_id new_name  age age_grade
# 0             1     Amit   25         a
# 1             4    Priya   27       NaN
# ...

# %% [markdown]
# **concat**

# %%
pd.concat([student_data,enrolment_data],axis=1).head()
# Out:
#    student_id new_name   age        department age_grade enrollment_id  \
# 0         1.0     Amit  25.0  Computer Science         a             1
# 1         2.0     Neha  26.0        Mechanical         b             2
# 2         3.0    Rahul  24.0        Electrical       NaN             3
# 3         4.0    Priya  27.0  Computer Science       NaN             4
# 4         5.0    Karan  27.0             Civil       NaN             5
#
#    student_id  course_id  semester  marks        date  passed
# 0         1.0      101.0       1.0   85.0  2024-01-15    True
# 1         1.0      102.0       1.0   78.0  2024-01-15   False
# 2         2.0      201.0       1.0   72.0  2024-01-16   False
# 3         3.0      301.0       1.0   68.0  2024-01-16   False
# 4         4.0      101.0       1.0   91.0  2024-01-17    True

# %% [markdown]
# **join**

# %% [markdown]
# ```python
# student_data.join(courses_data)
# ```

# %% [markdown]
# # **1️⃣4️⃣ String Operations**

# %%
student_data['department'].str.upper().head()
# Out:
# 0    COMPUTER SCIENCE
# 1          MECHANICAL
# 2          ELECTRICAL
# 3    COMPUTER SCIENCE
# 4               CIVIL
# Name: department, dtype: object

# %%
student_data['department'].str.lower().head()
# Out:
# 0    computer science
# 1          mechanical
# 2          electrical
# 3    computer science
# 4               civil
# Name: department, dtype: object

# %%
student_data['department'].str.contains('a').head()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# Name: department, dtype: object

# %%
student_data['department'].str.replace('a','b').head()
# Out:
# 0    Computer Science
# 1          Mechbnicbl
# 2          Electricbl
# 3    Computer Science
# 4               Civil
# Name: department, dtype: object

# %% [markdown]
# # **1️⃣5️⃣ Date & Time Operations**

# %%
enrolment_data["date"]=pd.to_datetime(enrolment_data['date'])

# %%
enrolment_data["year"]=enrolment_data["date"].dt.year

# %%
enrolment_data["month"]=enrolment_data["date"].dt.month

# %%
enrolment_data["day"]=enrolment_data["date"].dt.day

# %%
enrolment_data.head()
# Out:
#   enrollment_id  student_id  course_id  semester  marks       date  passed  \
# 0             1         1.0      101.0       1.0   85.0 2024-01-15    True
# 1             2         1.0      102.0       1.0   78.0 2024-01-15   False
# 2             3         2.0      201.0       1.0   72.0 2024-01-16   False
# 3             4         3.0      301.0       1.0   68.0 2024-01-16   False
# 4             5         4.0      101.0       1.0   91.0 2024-01-17    True
#
#      year  month   day
# 0  2024.0    1.0  15.0
# 1  2024.0    1.0  15.0
# 2  2024.0    1.0  16.0
# 3  2024.0    1.0  16.0
# 4  2024.0    1.0  17.0

# %% [markdown]
# # **1️⃣6️⃣ Duplicate Handling**

# %%
courses_data.duplicated().sum()
# Out:
# 0

# %%
courses_data.drop_duplicates(inplace=True)

# %%
courses_data.drop_duplicates(inplace=True)

# %%
courses_data.drop_duplicates(keep="first",inplace=True)
